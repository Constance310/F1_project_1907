# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data_preparation import kaggle_to_df

# %%
kaggle_to_df()
# Out:
#         raceId  driverId  lap  position  milliseconds                   name  \
# 0          841        20    1         1         98109  Australian Grand Prix
# 1          841        20    2         1         93006  Australian Grand Prix
# 2          841        20    3         1         92713  Australian Grand Prix
# 3          841        20    4         1         92803  Australian Grand Prix
# 4          841        20    5         1         92342  Australian Grand Prix
# ...        ...       ...  ...       ...           ...                    ...
# 589076    1144       857   54        10         87731   Abu Dhabi Grand Prix
# 589077    1144       857   55        10         87781   Abu Dhabi Grand Prix
# 589078    1144       857   56        10         87816   Abu Dhabi Grand Prix
# 589079    1144       857   57        10         88554   Abu Dhabi Grand Prix
# 589080    1144       857   58        10         88010   Abu Dhabi Grand Prix
#
# ...
